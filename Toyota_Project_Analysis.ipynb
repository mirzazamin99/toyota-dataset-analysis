# %% [markdown]
# ### Toyota Dataset Analysis
#  - A comprehensive exploratory data analysis of Toyota car models, their prices, years, and other key features.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
# %matplotlib inline
import warnings 
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv(r"D:\mypython work\projects\Toyota.csv")
df
# Out:
#                model  year  price transmission  mileage fuelType  tax   mpg  \
# 0               GT86  2016  16000       Manual    24089   Petrol  265  36.2
# 1               GT86  2017  15995       Manual    18615   Petrol  145  36.2
# 2               GT86  2015  13998       Manual    27469   Petrol  265  36.2
# 3               GT86  2017  18998       Manual    14736   Petrol  150  36.2
# 4               GT86  2017  17498       Manual    36284   Petrol  145  36.2
# ...              ...   ...    ...          ...      ...      ...  ...   ...
# 6733              IQ  2011   5500    Automatic    30000   Petrol   20  58.9
# 6734   Urban Cruiser  2011   4985       Manual    36154   Petrol  125  50.4
# 6735   Urban Cruiser  2012   4995       Manual    46000   Diesel  125  57.6
# 6736   Urban Cruiser  2011   3995       Manual    60700   Petrol  125  50.4
# 6737   Urban Cruiser  2011   4495       Manual    45128   Petrol  125  50.4
#
#       engineSize
# 0            2.0
# 1            2.0
# ...

# %%
df.head()
# Out:
#    model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0   GT86  2016  16000       Manual    24089   Petrol  265  36.2         2.0
# 1   GT86  2017  15995       Manual    18615   Petrol  145  36.2         2.0
# 2   GT86  2015  13998       Manual    27469   Petrol  265  36.2         2.0
# 3   GT86  2017  18998       Manual    14736   Petrol  150  36.2         2.0
# 4   GT86  2017  17498       Manual    36284   Petrol  145  36.2         2.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6738 entries, 0 to 6737
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         6738 non-null   object
#  1   year          6738 non-null   int64
#  2   price         6738 non-null   int64
#  3   transmission  6738 non-null   object
#  4   mileage       6738 non-null   int64
#  5   fuelType      6738 non-null   object
#  6   tax           6738 non-null   int64
#  7   mpg           6738 non-null   float64
#  8   engineSize    6738 non-null   float64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 473.9+ KB

# %%
df.describe()
# Out:
#               year         price        mileage          tax          mpg  \
# count  6738.000000   6738.000000    6738.000000  6738.000000  6738.000000
# mean   2016.748145  12522.391066   22857.413921    94.697240    63.042223
# std       2.204062   6345.017587   19125.464147    73.880776    15.836710
# min    1998.000000    850.000000       2.000000     0.000000     2.800000
# 25%    2016.000000   8290.000000    9446.000000     0.000000    55.400000
# 50%    2017.000000  10795.000000   18513.000000   135.000000    62.800000
# 75%    2018.000000  14995.000000   31063.750000   145.000000    69.000000
# max    2020.000000  59995.000000  174419.000000   565.000000   235.000000
#
#         engineSize
# count  6738.000000
# mean      1.471297
# std       0.436159
# min       0.000000
# 25%       1.000000
# 50%       1.500000
# 75%       1.800000
# max       4.500000

# %%
df.isnull().sum()
# Out:
# model           0
# year            0
# price           0
# transmission    0
# mileage         0
# fuelType        0
# tax             0
# mpg             0
# engineSize      0
# dtype: int64

# %%
df.loc[1:4]
# Out:
#    model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 1   GT86  2017  15995       Manual    18615   Petrol  145  36.2         2.0
# 2   GT86  2015  13998       Manual    27469   Petrol  265  36.2         2.0
# 3   GT86  2017  18998       Manual    14736   Petrol  150  36.2         2.0
# 4   GT86  2017  17498       Manual    36284   Petrol  145  36.2         2.0

# %%
df.duplicated().sum()
# Out:
# np.int64(39)

# %%
df.year.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4        True
#         ...
# 6733     True
# 6734     True
# 6735     True
# 6736     True
# 6737     True
# Name: year, Length: 6738, dtype: bool

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#                model  year  price transmission  mileage fuelType  tax   mpg  \
# 0               GT86  2016  16000       Manual    24089   Petrol  265  36.2
# 1               GT86  2017  15995       Manual    18615   Petrol  145  36.2
# 2               GT86  2015  13998       Manual    27469   Petrol  265  36.2
# 3               GT86  2017  18998       Manual    14736   Petrol  150  36.2
# 4               GT86  2017  17498       Manual    36284   Petrol  145  36.2
# ...              ...   ...    ...          ...      ...      ...  ...   ...
# 6733              IQ  2011   5500    Automatic    30000   Petrol   20  58.9
# 6734   Urban Cruiser  2011   4985       Manual    36154   Petrol  125  50.4
# 6735   Urban Cruiser  2012   4995       Manual    46000   Diesel  125  57.6
# 6736   Urban Cruiser  2011   3995       Manual    60700   Petrol  125  50.4
# 6737   Urban Cruiser  2011   4495       Manual    45128   Petrol  125  50.4
#
#       engineSize
# 0            2.0
# 1            2.0
# ...

# %%
#write a program to find the average price of toyota
dff=df["price"].mean()
dff
# Out:
# np.float64(12529.79907448873)

# %%
#write a program to find which year has most cars listed
dff=df["year"].value_counts()
dff
# Out:
# year
# 2017    2015
# 2019    1265
# 2018    1014
# 2016     990
# 2015     522
# 2014     351
# 2013     203
# 2020     127
# 2012      42
# 2011      40
# 2009      29
# 2007      20
# 2008      19
# 2010      18
# 2005      12
# 2006      11
# 2004       7
# 2003       6
# 2002       4
# 2001       1
# 1999       1
# 2000       1
# 1998       1
# Name: count, dtype: int64

# %%
df["price"].max()
# Out:
# 59995

# %%
#write a program to count how many cars have automatic transmachine
df[df["transmission"] == "Automatic"].shape[0]
# Out:
# 2651

# %%
df.head(3)
# Out:
#    model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0   GT86  2016  16000       Manual    24089   Petrol  265  36.2         2.0
# 1   GT86  2017  15995       Manual    18615   Petrol  145  36.2         2.0
# 2   GT86  2015  13998       Manual    27469   Petrol  265  36.2         2.0

# %%
#write a program to calculate the avg milage of diesel car
dff=df.groupby(["fuelType"])["mileage"].mean()
dff
# Out:
# fuelType
# Diesel    41661.135081
# Hybrid    24415.283333
# Other     17159.904762
# Petrol    19976.457368
# Name: mileage, dtype: float64

# %%
#write a program to calculate the avg milage of diesel car
df[df["fuelType"]=="Diesel"]["mileage"].mean()
# Out:
# np.float64(41661.13508064516)

# %%
#<<<< CORRELATION >>>>
#write the program to find the correlation between price and mileage
dff=df[["price","mileage"]].corr()
dff
# Out:
#             price   mileage
# price    1.000000 -0.300598
# mileage -0.300598  1.000000

# %%
#write a program to find to list top 10 most expensive cars
df["price"].sort_values(ascending=False).head(10)
# Out:
# 6711    59995
# 6670    54991
# 6695    54550
# 6688    52990
# 6672    52291
# 6707    51995
# 6703    51995
# 6704    51995
# 6667    50995
# 6661    50995
# Name: price, dtype: int64

# %%
df2 = df.nlargest(10,"price")
df2.to_csv("top10exp.csv")

# %%
df.nsmallest(10,"price")
# Out:
#          model  year  price transmission  mileage fuelType  tax   mpg  \
# 6427   Avensis  2003    850       Manual   167054   Diesel  205  48.7
# 289    Corolla  2001    899    Automatic    76000   Petrol  300  35.3
# 2447     Yaris  2002    950       Manual   104000   Petrol  200  40.4
# 2635     Yaris  2003    975       Manual   107000   Petrol  145  50.4
# 6431   Avensis  2007   1200    Automatic   120000   Petrol  300  36.7
# 263    Corolla  2004   1250       Manual   111000   Petrol  260  37.2
# 5496      Aygo  2005   1295       Manual    88836   Petrol   20  61.4
# 74     Corolla  2005   1300       Manual   129000   Petrol  260  36.7
# 259    Corolla  2003   1495       Manual    89000   Petrol  235  39.2
# 2830     Yaris  2006   1550       Manual   100418   Petrol  125  52.3
#
#       engineSize
# 6427         2.0
# 289          1.6
# 2447         1.5
# 2635         1.0
# 6431         1.8
# 263          1.8
# 5496         1.0
# 74           1.8
# 259          1.6
# ...

# %%
#write a program to compare average price by fuel type
df.groupby(["fuelType"])["price"].mean()
# Out:
# fuelType
# Diesel    15740.163306
# Hybrid    17187.811765
# Other     14121.161905
# Petrol     9754.594628
# Name: price, dtype: float64

# %%
#write a program to find the cars with mileage greater then the avg mileage of dataset
#avg mileage
dff=df["mileage"].mean()
df[df["mileage"]>dff]
# Out:
#                model  year  price transmission  mileage fuelType  tax   mpg  \
# 0               GT86  2016  16000       Manual    24089   Petrol  265  36.2
# 2               GT86  2015  13998       Manual    27469   Petrol  265  36.2
# 4               GT86  2017  17498       Manual    36284   Petrol  145  36.2
# 5               GT86  2017  15998       Manual    26919   Petrol  260  36.2
# 9               GT86  2016  13990       Manual    37999   Petrol  265  36.2
# ...              ...   ...    ...          ...      ...      ...  ...   ...
# 6733              IQ  2011   5500    Automatic    30000   Petrol   20  58.9
# 6734   Urban Cruiser  2011   4985       Manual    36154   Petrol  125  50.4
# 6735   Urban Cruiser  2012   4995       Manual    46000   Diesel  125  57.6
# 6736   Urban Cruiser  2011   3995       Manual    60700   Petrol  125  50.4
# 6737   Urban Cruiser  2011   4495       Manual    45128   Petrol  125  50.4
#
#       engineSize
# 0            2.0
# 2            2.0
# ...

# %%
#rename mileage to 
df.rename(columns={"mileage":"km_driven"},inplace = True)
df
# Out:
#                model  year  price transmission  km_driven fuelType  tax   mpg  \
# 0               GT86  2016  16000       Manual      24089   Petrol  265  36.2
# 1               GT86  2017  15995       Manual      18615   Petrol  145  36.2
# 2               GT86  2015  13998       Manual      27469   Petrol  265  36.2
# 3               GT86  2017  18998       Manual      14736   Petrol  150  36.2
# 4               GT86  2017  17498       Manual      36284   Petrol  145  36.2
# ...              ...   ...    ...          ...        ...      ...  ...   ...
# 6733              IQ  2011   5500    Automatic      30000   Petrol   20  58.9
# 6734   Urban Cruiser  2011   4985       Manual      36154   Petrol  125  50.4
# 6735   Urban Cruiser  2012   4995       Manual      46000   Diesel  125  57.6
# 6736   Urban Cruiser  2011   3995       Manual      60700   Petrol  125  50.4
# 6737   Urban Cruiser  2011   4495       Manual      45128   Petrol  125  50.4
#
#       engineSize
# ...

# %%
#write the program to calculate the average price of cars older then 10 years
#age is equal to 20025-2015
df["age"]=2025 - df["year"]
df.head(3)
# Out:
#    model  year  price transmission  km_driven fuelType  tax   mpg  engineSize  \
# 0   GT86  2016  16000       Manual      24089   Petrol  265  36.2         2.0
# 1   GT86  2017  15995       Manual      18615   Petrol  145  36.2         2.0
# 2   GT86  2015  13998       Manual      27469   Petrol  265  36.2         2.0
#
#    age
# 0    9
# 1    8
# 2   10

# %%
df
# Out:
#                model  year  price transmission  km_driven fuelType  tax   mpg  \
# 0               GT86  2016  16000       Manual      24089   Petrol  265  36.2
# 1               GT86  2017  15995       Manual      18615   Petrol  145  36.2
# 2               GT86  2015  13998       Manual      27469   Petrol  265  36.2
# 3               GT86  2017  18998       Manual      14736   Petrol  150  36.2
# 4               GT86  2017  17498       Manual      36284   Petrol  145  36.2
# ...              ...   ...    ...          ...        ...      ...  ...   ...
# 6733              IQ  2011   5500    Automatic      30000   Petrol   20  58.9
# 6734   Urban Cruiser  2011   4985       Manual      36154   Petrol  125  50.4
# 6735   Urban Cruiser  2012   4995       Manual      46000   Diesel  125  57.6
# 6736   Urban Cruiser  2011   3995       Manual      60700   Petrol  125  50.4
# 6737   Urban Cruiser  2011   4495       Manual      45128   Petrol  125  50.4
#
#       engineSize  age
# ...

# %%
df[df["age"]>10]
# Out:
#                model  year  price transmission  km_driven fuelType  tax   mpg  \
# 10              GT86  2013  10495       Manual      72000   Petrol  265  36.2
# 17              GT86  2014  12998       Manual      25499   Petrol  260  36.2
# 34              GT86  2013  11575       Manual      50584   Petrol  265  36.2
# 36              GT86  2014  14999       Manual      18389   Petrol  260  36.2
# 52              GT86  2014  13495       Manual      24667   Petrol  265  36.2
# ...              ...   ...    ...          ...        ...      ...  ...   ...
# 6733              IQ  2011   5500    Automatic      30000   Petrol   20  58.9
# 6734   Urban Cruiser  2011   4985       Manual      36154   Petrol  125  50.4
# 6735   Urban Cruiser  2012   4995       Manual      46000   Diesel  125  57.6
# 6736   Urban Cruiser  2011   3995       Manual      60700   Petrol  125  50.4
# 6737   Urban Cruiser  2011   4495       Manual      45128   Petrol  125  50.4
#
#       engineSize  age
# ...

# %%
# write a program to find the top 5 models with the highest resale value
df["price"].sort_values(ascending=False)
# Out:
# 6711    59995
# 6670    54991
# 6695    54550
# 6688    52990
# 6672    52291
#         ...
# 6431     1200
# 2635      975
# 2447      950
# 289       899
# 6427      850
# Name: price, Length: 6699, dtype: int64

# %%
#on the basis of price
df.nlargest(5,"price")
# Out:
#               model  year  price transmission  km_driven fuelType  tax   mpg  \
# 6711          Supra  2019  59995    Automatic       9909    Other  150  34.5
# 6670   Land Cruiser  2019  54991    Semi-Auto       1000   Diesel  145  30.1
# 6695   Land Cruiser  2020  54550    Automatic       4000   Diesel  150  30.1
# 6688   Land Cruiser  2020  52990    Automatic       1244   Diesel  145  30.1
# 6672   Land Cruiser  2020  52291    Semi-Auto       3104   Diesel  145  30.1
#
#       engineSize  age
# 6711         3.0    6
# 6670         2.8    6
# 6695         2.8    5
# 6688         2.8    5
# 6672         2.8    5

# %%
# on the basis of model
# write a program to find the top 5 models with the highest resale value
dff=df.groupby(["model"])["price"].mean().sort_values(ascending=False).head(5)
dff
# Out:
# model
# Supra           50741.000000
# Land Cruiser    36487.156863
# PROACE VERSO    28680.200000
# Camry           26910.090909
# Hilux           21581.176471
# Name: price, dtype: float64

# %%
# calculate the % of desiel cars in the datasets
df.shape[0]
# Out:
# 6699

# %%
dff = df[df["fuelType"]=="Diesel"]
(dff.shape[0]/df.shape[0])*100
# Out:
# 7.404090162710853

# %%
#write a program tofinmd cars that have 75th percentile 
dff=df["price"].quantile(0.75)
df[df["price"]>dff]
# Out:
#        model  year  price transmission  km_driven fuelType  tax   mpg  \
# 0       GT86  2016  16000       Manual      24089   Petrol  265  36.2
# 1       GT86  2017  15995       Manual      18615   Petrol  145  36.2
# 3       GT86  2017  18998       Manual      14736   Petrol  150  36.2
# 4       GT86  2017  17498       Manual      36284   Petrol  145  36.2
# 5       GT86  2017  15998       Manual      26919   Petrol  260  36.2
# ...      ...   ...    ...          ...        ...      ...  ...   ...
# 6718   Camry  2019  26491    Automatic       4416   Hybrid  135  52.3
# 6719   Camry  2019  27550    Automatic       4189   Hybrid  135  52.3
# 6720   Camry  2019  25490    Automatic       6340   Hybrid  135  52.3
# 6721   Camry  2019  26990    Automatic       3000   Hybrid  135  52.3
# 6722   Camry  2019  25990    Automatic      10732   Hybrid  135  52.3
#
#       engineSize  age
# 0            2.0    9
# 1            2.0    8
# 3            2.0    8
# 4            2.0    8
# ...

# %%
df.describe()
# Out:
#               year         price      km_driven          tax          mpg  \
# count  6699.000000   6699.000000    6699.000000  6699.000000  6699.000000
# mean   2016.742797  12529.799074   22889.588745    94.549933    63.078728
# std       2.205271   6358.562625   19109.288501    73.942649    15.861037
# min    1998.000000    850.000000       2.000000     0.000000     2.800000
# 25%    2016.000000   8266.500000    9488.500000     0.000000    55.400000
# 50%    2017.000000  10798.000000   18571.000000   135.000000    62.800000
# 75%    2018.000000  14995.000000   31059.500000   145.000000    70.600000
# max    2020.000000  59995.000000  174419.000000   565.000000   235.000000
#
#         engineSize          age
# count  6699.000000  6699.000000
# mean      1.471996     8.257203
# std       0.435624     2.205271
# min       0.000000     5.000000
# 25%       1.000000     7.000000
# 50%       1.500000     8.000000
# 75%       1.800000     9.000000
# max       4.500000    27.000000

# %% [markdown]
# write a program to count how many cars have mileage above 90th percentile

# %%
df[df["km_driven"]>df["km_driven"].quantile(0.90)].shape

# %% [markdown]
# write a program to find how many cars have both low mileage below median and high price above median

# %%
mileage_median=df["km_driven"].median()
price_median=df["price"].median()
dff=df[(df["km_driven"]<mileage_median) & (df["price"]>price_median)]
dff.shape[0]
# Out:
# 1927

# %% [markdown]
# Write a program to visualize the distribution of car prices using a histogram.

# %%
plt.figure(figsize = (12,6),dpi=400)
sns.histplot(df["price"],bins=20)
plt.show()

# %% [markdown]
# Write a program to draw a bar chart showing number of cars for each fuel type.

# %%
df["fuelType"].value_counts()
# Out:
# fuelType
# Petrol    4058
# Hybrid    2040
# Diesel     496
# Other      105
# Name: count, dtype: int64

# %%
# "Set1" – bold & bright

# "Set2" – softer

# "Set3" – many pastel colors

# "Paired" – good contrast pairs

# %%
plt.figure(figsize = (12,6),dpi=400)
sns.countplot(x= "fuelType", data=df, palette = "Set1")
plt.show()

# %%
df.head(1)
# Out:
#    model  year  price transmission  km_driven fuelType  tax   mpg  engineSize  \
# 0   GT86  2016  16000       Manual      24089   Petrol  265  36.2         2.0
#
#    age
# 0    9

# %% [markdown]
#  visualize between mileage and age

# %%
df["age"] = 2025 -df["year"]
df.head(1)
# Out:
#    model  year  price transmission  km_driven fuelType  tax   mpg  engineSize  \
# 0   GT86  2016  16000       Manual      24089   Petrol  265  36.2         2.0
#
#    age
# 0    9

# %%
plt.figure(figsize = (12,6),dpi=400)
sns.scatterplot(x= "age",y = "price",data=df)
plt.show()

# %% [markdown]
# Write a program to compare car prices across different fuel types using boxplot.

# %%
plt.figure(figsize = (12,6),dpi=400)
sns.boxplot(x= "fuelType",y = "price",data=df)
plt.show()

# %% [markdown]
# engine size with price

# %%
plt.figure(figsize = (12,6),dpi=500)
sns.lineplot(x= "engineSize",y = "price",data=df)
plt.show()

# %% [markdown]
# Write a program to draw a correlation heatmap for numerical columns.

# %%
df.head(1)
corr = df.corr(numeric_only = True)
plt.figure(figsize = (12,6),dpi=500)
sns.heatmap(corr,annot=True,cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %%
cols = df[["price","mpg","engineSize","age"]]
cols
# Out:
#       price   mpg  engineSize  age
# 0     16000  36.2         2.0    9
# 1     15995  36.2         2.0    8
# 2     13998  36.2         2.0   10
# 3     18998  36.2         2.0    8
# 4     17498  36.2         2.0    8
# ...     ...   ...         ...  ...
# 6733   5500  58.9         1.0   14
# 6734   4985  50.4         1.3   14
# 6735   4995  57.6         1.4   13
# 6736   3995  50.4         1.3   14
# 6737   4495  50.4         1.3   14
#
# [6699 rows x 4 columns]

# %%
sns.pairplot(df)
plt.show()

# %% [markdown]
# Write a program to visualize price vs age colored by fuel type.

# %%
plt.figure(figsize = (12,6),dpi=500)
sns.scatterplot(x= "age",y = "price", hue = "fuelType",data=df)
plt.show()

# %% [markdown]
# Write a program to visualize top 10 most expensive cars.

# %%
df2 = df.sort_values("price",ascending = False).head(10)
plt.figure(figsize = (12,6),dpi=500)
sns.barplot(x= df2["model"],y = df2["price"],palette="Set1")
plt.show()
